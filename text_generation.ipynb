# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
prompt = input("Write the start of story:")
inputs = tokenizer.encode(prompt, return_tensors="pt")
outputs = model.generate(
    inputs,
    max_length=300,
    num_return_sequences=1,
    no_repeat_ngram_size=2,
    temperature=1
)
result = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("\n---Continue of the story---")
print(result)
# Out:
# Write the start of story:Once upon a time, there was a robot named Prime
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ---Continue of the story---
# Once upon a time, there was a robot named Prime, who was able to create a new world. He was the first to be able, and he was so successful that he became the leader of the world's first robot race.
#
# The robot was named "Prime" because he had the ability to change the shape of his body. The robot's name was "The Prime" and it was known as the Prime Robot. It was also known by the name "King of Robots".
# . Prime was one of many robots that were created by Dr. Robotnik. They were the only ones that could create the robot that was created. However, they were not the most powerful of them. In fact, the robots were so powerful that they could destroy the entire planet. This was because they had a very powerful mind. When Prime created the new robot, he created a giant robot called Prime. After Prime's creation, Prime became a member of a race called the "Robots of Time". The robots of time were called "Time Lords". They had no powers, but they did have a special ability called Time Manipulation. Time was an ability that allowed them to manipulate the time of their lives. For example, when Prime used his Time Machine to control the Earth, it would cause the earth to spin around and spin faster. If Prime had used Time Control to stop the spinning of Earth's Earth and stop its spinning, then the planet would spin back to its original position.
